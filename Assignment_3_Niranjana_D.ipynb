# %% [markdown]
# ## ASSIGNMENT 3
#
#
# NIRANJANA D
#
# 21BEC1655

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #task 2 - load the data set

# %%
df = pd.read_csv('/content/penguins_size.csv')
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.sex = le.fit_transform(df.sex)
df.island = le.fit_transform(df.island)
df.species = le.fit_transform(df.species)
df
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2              39.1             18.7              181.0
# 1          0       2              39.5             17.4              186.0
# 2          0       2              40.3             18.0              195.0
# 3          0       2               NaN              NaN                NaN
# 4          0       2              36.7             19.3              193.0
# ..       ...     ...               ...              ...                ...
# 339        2       0               NaN              NaN                NaN
# 340        2       0              46.8             14.3              215.0
# 341        2       0              50.4             15.7              222.0
# 342        2       0              45.2             14.8              212.0
# 343        2       0              49.9             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# ...

# %% [markdown]
# # task 3 - visualization

# %% [markdown]
# UNIVARIENT ANALYSIS

# %%
## UNIVARIENT
sns.distplot(df.culmen_length_mm)
# Out:
# <ipython-input-5-d785f7778fda>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_length_mm)
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
# UNIVARIENT
sns.displot(df.culmen_length_mm)

# %%
df
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2              39.1             18.7              181.0
# 1          0       2              39.5             17.4              186.0
# 2          0       2              40.3             18.0              195.0
# 3          0       2               NaN              NaN                NaN
# 4          0       2              36.7             19.3              193.0
# ..       ...     ...               ...              ...                ...
# 339        2       0               NaN              NaN                NaN
# 340        2       0              46.8             14.3              215.0
# 341        2       0              50.4             15.7              222.0
# 342        2       0              45.2             14.8              212.0
# 343        2       0              49.9             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# ...

# %%
#### barplot -- univarient

sns.barplot(x=df.culmen_length_mm.value_counts().index,y=(df.culmen_length_mm.value_counts()))
# Out:
# <Axes: ylabel='culmen_length_mm'>

# %%
sns.barplot(x=df.sex.value_counts().index,y=(df.sex.value_counts()))
# Out:
# <Axes: ylabel='sex'>

# %% [markdown]
# BIVARIENT ANALYSIS

# %%
sns.lineplot(x= df.flipper_length_mm ,y= df.culmen_length_mm)  ## lineplot -- bivarient
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='culmen_length_mm'>

# %% [markdown]
# MULTIVARIENT ANALYSIS

# %%
sns.heatmap(df.corr(),annot=True)  ## heatmap
# Out:
# <Axes: >

# %% [markdown]
# ## task 4

# %%
##  Perform descriptive statistics on the dataset.
df.describe()
# Out:
#           species      island  culmen_length_mm  culmen_depth_mm  \
# count  344.000000  344.000000        342.000000       342.000000
# mean     0.918605    0.662791         43.921930        17.151170
# std      0.893320    0.726194          5.459584         1.974793
# min      0.000000    0.000000         32.100000        13.100000
# 25%      0.000000    0.000000         39.225000        15.600000
# 50%      1.000000    1.000000         44.450000        17.300000
# 75%      2.000000    1.000000         48.500000        18.700000
# max      2.000000    2.000000         59.600000        21.500000
#
#        flipper_length_mm  body_mass_g         sex
# count         342.000000   342.000000  344.000000
# mean          200.915205  4201.754386    1.543605
# std            14.061714   801.954536    0.559430
# min           172.000000  2700.000000    0.000000
# 25%           190.000000  3550.000000    1.000000
# 50%           197.000000  4050.000000    2.000000
# ...

# %% [markdown]
# # task 5

# %%
##  Check for Missing values and deal with them.
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                  False
# dtype: bool

# %%
### replacing the null values with median since null is present in numerical columns

df['culmen_length_mm'].fillna(df['culmen_length_mm'].median(),inplace = True)
df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].median(),inplace = True)
df['flipper_length_mm'].fillna(df['flipper_length_mm'].median(),inplace = True)
df['body_mass_g'].fillna(df['body_mass_g'].median(),inplace = True)

df
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2             39.10             18.7              181.0
# 1          0       2             39.50             17.4              186.0
# 2          0       2             40.30             18.0              195.0
# 3          0       2             44.45             17.3              197.0
# 4          0       2             36.70             19.3              193.0
# ..       ...     ...               ...              ...                ...
# 339        2       0             44.45             17.3              197.0
# 340        2       0             46.80             14.3              215.0
# 341        2       0             50.40             15.7              222.0
# 342        2       0             45.20             14.8              212.0
# 343        2       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# ...

# %% [markdown]
# # task 6

# %%
## finding outliers
sns.boxplot(df.flipper_length_mm)  #### boxplot
# Out:
# <Axes: >

# %%
sns.boxplot(df.body_mass_g)
# Out:
# <Axes: >

# %%
sns.boxplot(df.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
'''
 therefore in task 6 there is no outliers are found
'''
# Out:
# '\n therefore in task 6 there is no outliers are found\n'

# %% [markdown]
# #task 7

# %%
## Check the correlation of independent variables with the target
df.corr().species.sort_values(ascending=False)
# Out:
# species              1.000000
# flipper_length_mm    0.850819
# body_mass_g          0.747547
# culmen_length_mm     0.728706
# sex                 -0.010379
# island              -0.635659
# culmen_depth_mm     -0.741282
# Name: species, dtype: float64

# %% [markdown]
# # task 8

# %%
## Check for Categorical columns and perform encoding.
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()


df.sex = le.fit_transform(df.sex)
df.island = le.fit_transform(df.island)
df.species = le.fit_transform(df.species)
df
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2             39.10             18.7              181.0
# 1          0       2             39.50             17.4              186.0
# 2          0       2             40.30             18.0              195.0
# 3          0       2             44.45             17.3              197.0
# 4          0       2             36.70             19.3              193.0
# ..       ...     ...               ...              ...                ...
# 339        2       0             44.45             17.3              197.0
# 340        2       0             46.80             14.3              215.0
# 341        2       0             50.40             15.7              222.0
# 342        2       0             45.20             14.8              212.0
# 343        2       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# ...

# %% [markdown]
# # task 9

# %%
## Split the data into dependent and independent variables.
## x and y split..independent and dependant variable

x=df.drop(columns =['species'],axis=1)
x
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0         2             39.10             18.7              181.0
# 1         2             39.50             17.4              186.0
# 2         2             40.30             18.0              195.0
# 3         2             44.45             17.3              197.0
# 4         2             36.70             19.3              193.0
# ..      ...               ...              ...                ...
# 339       0             44.45             17.3              197.0
# 340       0             46.80             14.3              215.0
# 341       0             50.40             15.7              222.0
# 342       0             45.20             14.8              212.0
# 343       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# 1         3800.0    1
# 2         3250.0    1
# 3         4050.0    3
# 4         3450.0    1
# ..           ...  ...
# ...

# %%
y=df.species
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: species, Length: 344, dtype: int64

# %% [markdown]
# # task 10

# %%
## scaling the data
from sklearn.preprocessing import MinMaxScaler     ## value lies bw 0 to 1 in minmaxscaler
scale= MinMaxScaler()

# %%
x_scaled=pd.DataFrame(scale.fit_transform(x),columns=x.columns)

# %%
x_scaled
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0       1.0          0.254545         0.666667           0.152542
# 1       1.0          0.269091         0.511905           0.237288
# 2       1.0          0.298182         0.583333           0.389831
# 3       1.0          0.449091         0.500000           0.423729
# 4       1.0          0.167273         0.738095           0.355932
# ..      ...               ...              ...                ...
# 339     0.0          0.449091         0.500000           0.423729
# 340     0.0          0.534545         0.142857           0.728814
# 341     0.0          0.665455         0.309524           0.847458
# 342     0.0          0.476364         0.202381           0.677966
# 343     0.0          0.647273         0.357143           0.694915
#
#      body_mass_g       sex
# 0       0.291667  0.666667
# 1       0.305556  0.333333
# 2       0.152778  0.333333
# 3       0.375000  1.000000
# 4       0.208333  0.333333
# ...

# %% [markdown]
# # task 11

# %%
##  Split the data into training and testing

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.3,random_state=0)

# %%
x_train
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 219     0.5          0.658182         0.666667           0.440678
# 271     0.0          0.596364         0.119048           0.813559
# 266     0.0          0.487273         0.095238           0.644068
# 335     0.0          0.836364         0.345238           0.983051
# 217     0.5          0.636364         0.607143           0.355932
# ..      ...               ...              ...                ...
# 323     0.0          0.618182         0.226190           0.949153
# 192     0.5          0.614545         0.761905           0.644068
# 117     1.0          0.189091         0.880952           0.457627
# 47      0.5          0.196364         0.690476           0.118644
# 172     0.5          0.374545         0.500000           0.152542
#
#      body_mass_g       sex
# 219     0.298611  0.333333
# 271     0.722222  0.666667
# 266     0.416667  0.333333
# 335     0.875000  0.666667
# 217     0.298611  0.666667
# ...

# %%
x_test
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 141     0.5          0.309091         0.488095           0.254237
# 6       1.0          0.247273         0.559524           0.152542
# 60      0.0          0.130909         0.452381           0.220339
# 249     0.0          0.650909         0.261905           0.813559
# 54      0.0          0.087273         0.595238           0.254237
# ..      ...               ...              ...                ...
# 81      1.0          0.392727         0.535714           0.406780
# 1       1.0          0.269091         0.511905           0.237288
# 120     1.0          0.149091         0.488095           0.254237
# 8       1.0          0.072727         0.595238           0.355932
# 313     0.0          0.632727         0.357143           0.881356
#
#      body_mass_g       sex
# 141     0.215278  0.666667
# 6       0.256944  0.333333
# 60      0.125000  0.333333
# 249     0.791667  0.666667
# 54      0.055556  0.333333
# ...

# %%
y_train
# Out:
# 219    1
# 271    2
# 266    2
# 335    2
# 217    1
#       ..
# 323    2
# 192    1
# 117    0
# 47     0
# 172    1
# Name: species, Length: 240, dtype: int64

# %%
y_test
# Out:
# 141    0
# 6      0
# 60     0
# 249    2
# 54     0
#       ..
# 81     0
# 1      0
# 120    0
# 8      0
# 313    2
# Name: species, Length: 104, dtype: int64

# %% [markdown]
# # task 12

# %%
## check the training and testing data shape.

# %%
x_train.shape
# Out:
# (240, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
x_test.shape
# Out:
# (104, 6)

# %%
y_test.shape
# Out:
# (104,)
